# %%
import os
import pandas as pd

directory = os.getcwd() + "/activity-8/0/"
dfs = []

# print(directory)

for root, subdirectories, files in os.walk(directory):
#     for subdirectory in subdirectories:
#         print(os.path.join(root, subdirectory))
#     for file in files:
#         print(os.path.join(root, file))
    for file in files:
        # print(file)
        if file.endswith("res.csv"):
            print(os.path.join(root, file))
            df = pd.read_csv(os.path.join(root, file), sep = ";")
#             print(len(df))
            dfs.append(df)
            
# dfs
# Out:
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k38/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k1/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k24/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k39/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k22/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k23/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k37/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k3/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k14/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k5/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k27/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k17/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k36/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k11/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k20/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k29/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k18/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k31/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k12/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k4/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k16/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k2/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k32/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k9/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k8/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k15/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k35/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k25/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k19/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k13/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k6/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k40/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k34/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k21/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k28/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k26/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k7/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k10/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k33/res.csv
# /home/joao/Projects/UFJF/gecco2022_ggp_har/output/activity-8/0/k30/res.csv

# %%
results = pd.concat(dfs)
# results = results[results.seed.isin([1, 2, 3])]
results.columns = ['seed', 'training', 'validation', 'test', 'model']
results.describe()
# Out:
#         seed    training  validation        test  \
# count    234  234.000000  234.000000  234.000000
# unique    10  203.000000  114.000000   42.000000
# top        1    0.480903    0.383929    0.223214
# freq      30    3.000000    9.000000   16.000000
#
#                                                     model
# count                                                 234
# unique                                                234
# top     emotional physical -1 0.25 != if-else mental m...
# freq                                                    1

# %%
results[results.test == results.test.min()]
# Out:
#   seed  training validation      test  \
# 1    2  0.470486   0.502976  0.044643
#
#                                                model
# 1  mental emotional physical IT_p_Total_mad 1 / I...

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

from __future__ import division
import random
from sympy import *

IF_ELSE = set(['if-else'])
BINARY_OPERATORS = set(['+', '-', '*', '/', '^', '<', '<=', '==', '>=', '>', '!=', 'and', 'or'])
UNARY_OPERATORS = set(['log', 'sqrt', 'exp', 'sin'])

### POSTFIX ===> INFIX ###
'''
1) When see an operand, push
2) When see an operator, pop out two numbers, connect them into a substring and push back to the stack
3) the top of the stack is the final infix expression.
'''
def postfix_to_infix(formula):
    stack = []
    for ch in formula.split():
        if ch == "<-":
            b = stack.pop()
            a = stack.pop()
            expr = "v[" + a + "] = " + b + ""
            stack.append(expr)
        elif ch == "->":
            a = stack.pop()
            expr = "v[" + a + "]"
            stack.append(expr)
        elif ch in BINARY_OPERATORS:
            if ch == "^":
                ch = "**"
            b = stack.pop()
            a = stack.pop()
            expr = "(" + a + ch + b + ")"
            stack.append(expr)
        elif ch in UNARY_OPERATORS:
            a = stack.pop()
            expr = ch + "(" + a + ")"
            stack.append(expr)
        elif ch in IF_ELSE:
            c = stack.pop()
            b = stack.pop()
            a = stack.pop()
            expr = "if(" + c + "){\n" + a + "\n}else{\n" + b + "\n}"
            stack.append(expr)
        else:
            stack.append(ch)

    return stack

def postfix_to_infix_python(formula, constants):
    stack = []
    c_counter = 0
    for ch in formula.split():
        if ch == "<-":
            b = stack.pop()
            a = stack.pop()
            expr = "v[" + a + "] = " + b + ""
            stack.append(expr)
        elif ch == "->":
            a = stack.pop()
            expr = "v[" + a + "]"
            stack.append(expr)
        elif ch in BINARY_OPERATORS:
            if ch == "^":
                ch = "**"
            b = stack.pop()
            a = stack.pop()
            expr = "(" + a + ch + b + ")"
            stack.append(expr)
        elif ch in UNARY_OPERATORS:
            a = stack.pop()
            expr = ch + "(" + a + ")"
            stack.append(expr)
        elif ch in IF_ELSE:
            c = stack.pop()
            b = stack.pop()
            a = stack.pop()
            expr = "if(" + c + "):\n" + a + "\nelse:\n" + b + "\n"
            stack.append(expr)
        elif ch in ["_c_"]:            
            stack.append(str(constants[c_counter]))
            c_counter = c_counter + 1
        else:
            stack.append(ch)

    return stack

# if __name__ == '__main__':
#     infix = postfix_to_infix_pyton("cost income - cost return / + cost income - return income / + + cost return cost + - cost return * cost / + * income income return / ^ return return return * income cost * * * * /")
#     print("PG output: " + infix)
#     # print("Simplify: " + str(simplify(infix)))

# %%
infix = []

for i, model in results.iterrows():
    infix.append(postfix_to_infix_python(model.model, []))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <module>
#       1 infix = []
# ----> 3 for i, model in results.iterrows():
#       4     infix.append(postfix_to_infix_python(model.model, []))
#
# NameError: name 'results' is not defined

# %%
results['infix'] = infix

# %%
# results.to_csv("PG/output/activity-000/results.csv", index = None)

# %%
print(list(results[results.test.min() == results.test].model))
# Out:
# ['mental emotional physical IT_p_Total_mad 1 / IT_PSD_baseline <= if-else ARM_EDA_Filt2_median IT_PSD_baseline <= if-else mental physical 0.5 ECG_p_MF_kurtosis HAND_EDA_Filt2_harmmean / ARM_EDA_Filt2_skewness -1 + * == if-else IT_RF_harmmean -0.75 > HAND_EDA_processed_prctile75 ECG_p_MF_geomean(abs) != or 0.5 HAND_EDA_processed_mad >= IT_RF_harmmean -0.75 > ARM_EDA_Functionals_power_Filt2min IT_LF_mad >= or and and if-else mental emotional emotional ECG_p_VFL_mad IT_RF_baseline < if-else mental mental -0.75 0 > if-else ECG_HR_min_div_harmmean 0.25 <= if-else ECG_Logstd IT_RF_mad ECG_RR_window_min * <= if-else neutral IT_BRV_geomean(abs) 0.5 - ECG_original_prctile25 + IT_HF_kurtosis 0.5 ^ < if-else IT_PSD_baseline IT_PSD_baseline 0.5 * < IT_PSD_baseline ECG_original_baseline 1 / < ECG_RR_window_prctile25 ECG_PSD_prctile75 <= and or if-else ']

# %%
results
# Out:
#    seed  training validation      test  \
# 0     1  0.348214   0.348214  0.223214
# 1     2  0.358631   0.392857  0.214286
# 2     3  0.410466   0.404762  0.276786
# 3     4  0.288938   0.247024  0.205357
# 4     5  0.297619    0.27381  0.151786
# ..  ...       ...        ...       ...
# 5     6  0.319196   0.407738     0.125
# 6     7  0.343502   0.196429  0.151786
# 7     8  0.274058   0.386905  0.089286
# 8     9  0.271577   0.407738     0.125
# 9    10  0.304812       0.25     0.125
#
#                                                 model  \
# 0   emotional physical -1 0.25 != if-else mental m...
# 1   physical neutral neutral HAND_EDA_processed_me...
# 2   physical emotional IT_RF_kurtosis IT_BRV_std <...
# 3   physical neutral IT_MF_skewness IT_MF_HF + IT_...
# 4   neutral neutral neutral 0 -1 <= if-else physic...
# ..                                                ...
# 5   mental mental emotional 0.25 HAND_EDA_processe...
# 6   neutral neutral mental IT_BRV_kurtosis 0 > if-...
# 7   mental neutral physical 0 IT_BRV_std < if-else...
# 8   emotional neutral emotional ARM_EDA_Original_s...
# 9   neutral mental emotional ECG_Load_index ARM_ED...
#
#                                                 infix
# 0   if(((((ECG_original_mean<0.75)or(ARM_EDA_Filt2...
# 1   if(((((0.75<=IT_LF_max)or((1/-0.75)==1))or((EC...
# 2   if(((((ARM_EDA_Original_min>HAND_EDA_processed...
# 3   if((((ECG_amplitude_RR_median-0.5)<=0.75)or(((...
# 4   if((ECG_hrv_mean>((-1*-0.5)*0.75))):\nif(((ARM...
# ..                                                ...
# 5   if((ECG_RR_window_median>(0.5*ECG_RR_window_ba...
# 6   if(((((ARM_EDA_Filt1_min**0.25)==1)or((IT_BRV_...
# 7   if(((((-1<=IT_RF_prctile75)and(ECG_hrv_trimmea...
# 8   if(((((0.5<(HAND_EDA_processed_harmmean/-0.75)...
# 9   if(((ARM_EDA_Functionals_power_Fil12min<=0.5)a...
#
# [234 rows x 6 columns]

# %%
postfix_to_infix_python("1 2 <- 1 -> x +", [])
# Out:
# '(v[1]+x)'
