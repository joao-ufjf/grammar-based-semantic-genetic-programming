# %%
import subprocess
import threading
import os
import shutil

# %%
import asyncio
import asyncio.subprocess
import datetime

start = datetime.datetime.now()

sem = asyncio.Semaphore(14)

commands = None
with open('commands.txt', 'r') as file:
    commands = file.readlines()

executed = None
with open('executed.txt', 'r') as file:
    executed = file.readlines()

async def do_job(c, total, command):
    async with sem:  # Don't run more than 10 simultaneous jobs below
        print(c/total, command)
        proc = await asyncio.create_subprocess_shell(command, stdout=asyncio.subprocess.PIPE)
        output = await proc.stdout.read()

        proc = await asyncio.create_subprocess_shell('''echo "{}" >> executed.txt'''.format(command[:-1]), stdout=asyncio.subprocess.PIPE)
        output = await proc.stdout.read()
    
tasks = []
total = len(commands)
for c, command in enumerate(commands[:]):
    if command not in executed:
        task = asyncio.create_task(do_job(c, total, command))
        tasks.append(task)

await asyncio.gather(*tasks)

print(datetime.datetime.now() - start)
# Out:
# 0.0 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/DEF/0.00E+00/1.00E+00/ 10 0 0 0 0 0 500 0 0 0.00E+00 1.00E+00 0
#
# 1.984126984126984e-05 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-03/1.00E-02/ 10 0 0 0 0 0 500 1 0 1.00E-03 1.00E-02 0
#
# 3.968253968253968e-05 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-03/1.00E-01/ 10 0 0 0 0 0 500 1 0 1.00E-03 1.00E-01 0
#
# 5.9523809523809524e-05 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-03/1.00E+00/ 10 0 0 0 0 0 500 1 0 1.00E-03 1.00E+00 0
#
# 7.936507936507937e-05 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-03/1.00E+01/ 10 0 0 0 0 0 500 1 0 1.00E-03 1.00E+01 0
#
# 9.92063492063492e-05 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-02/1.00E-01/ 10 0 0 0 0 0 500 1 0 1.00E-02 1.00E-01 0
#
# 0.00011904761904761905 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-02/1.00E+00/ 10 0 0 0 0 0 500 1 0 1.00E-02 1.00E+00 0
#
# 0.0001388888888888889 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-02/1.00E+01/ 10 0 0 0 0 0 500 1 0 1.00E-02 1.00E+01 0
#
# 0.00015873015873015873 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-01/1.00E+00/ 10 0 0 0 0 0 500 1 0 1.00E-01 1.00E+00 0
#
# 0.00017857142857142857 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E-01/1.00E+01/ 10 0 0 0 0 0 500 1 0 1.00E-01 1.00E+01 0
#
# 0.0001984126984126984 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/RSC/1.00E+00/1.00E+01/ 10 0 0 0 0 0 500 1 0 1.00E+00 1.00E+01 0
#
# 0.00021825396825396825 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/FVSC/1.00E-03/1.00E-02/ 10 0 0 0 0 0 500 2 0 1.00E-03 1.00E-02 0
#
# 0.0002380952380952381 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/FVSC/1.00E-03/1.00E-01/ 10 0 0 0 0 0 500 2 0 1.00E-03 1.00E-01 0
#
# 0.00025793650793650796 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS
./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-03/1.00E-01/ 10 0 0 0 0 0 500 4 0 1.00E-03 1.00E-01 0
#
# 0.0006547619047619047 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-03/1.00E+00/ 10 0 0 0 0 0 500 4 0 1.00E-03 1.00E+00 0
#
# 0.0006746031746031747 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-03/1.00E+01/ 10 0 0 0 0 0 500 4 0 1.00E-03 1.00E+01 0
#
# 0.0006944444444444445 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-02/1.00E-01/ 10 0 0 0 0 0 500 4 0 1.00E-02 1.00E-01 0
#
# 0.0007142857142857143 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-02/1.00E+00/ 10 0 0 0 0 0 500 4 0 1.00E-02 1.00E+00 0
#
# 0.0007341269841269841 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-02/1.00E+01/ 10 0 0 0 0 0 500 4 0 1.00E-02 1.00E+01 0
#
# 0.000753968253968254 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-01/1.00E+00/ 10 0 0 0 0 0 500 4 0 1.00E-01 1.00E+00 0
#
# 0.0007738095238095238 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E-01/1.00E+01/ 10 0 0 0 0 0 500 4 0 1.00E-01 1.00E+01 0
#
# 0.0007936507936507937 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SSC/1.00E+00/1.00E+01/ 10 0 0 0 0 0 500 4 0 1.00E+00 1.00E+01 0
#
# 0.0008134920634920635 ./bin/Release/gpufjf 0 input/nicolau/grammars/grammar_2_fp input/nicolau/fs/f1/50/original/data input/nicolau/fs/groups/50 0 input/nicolau/fs/results/f1/50/original/ABS/SCPS/0.00E+00/1.00E+00/ 10 0 0 0 0 0 500 5 0 0.00E+00 1.00E+00 0
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[10], line 21, in do_job(c, total, command)
#      20 proc = await asyncio.create_subprocess_shell(command, stdout=asyncio.subprocess.PIPE)
# ---> 21 output = await proc.stdout.read()
#      23 proc = await asyncio.create_subprocess_shell('''echo "{}" >> executed.txt'''.format(command[:-1]), stdout=asyncio.subprocess.PIPE)
#
# File ~/anaconda3/envs/whisperx/lib/python3.10/asyncio/streams.py:662, in StreamReader.read(self, n)
#     661 while True:
# --> 662     block = await self.read(self._limit)
#     663     if not block:
#
# File ~/anaconda3/envs/whisperx/lib/python3.10/asyncio/streams.py:669, in StreamReader.read(self, n)
#     668 if not self._buffer and not self._eof:
# --> 669     await self._wait_for_data('read')
#     671 # This will work right even if buffer is less than n bytes
#
# File ~/anaconda3/envs/whisperx/lib/python3.10/asyncio/streams.py:501, in StreamReader._wait_for_data(self, func_name)
#     500 try:
# --> 501     await self._waiter
#     502 finally:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[10], line 33
#      30         task = asyncio.create_task(do_job(c, total, command))
#      31         tasks.append(task)
# ---> 33 await asyncio.gather(*tasks)
#      35 print(datetime.datetime.now() - start)
#
# CancelledError:
